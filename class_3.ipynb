# %% [markdown]
# <a href="https://colab.research.google.com/github/ad7-ux/student-center/blob/main/class_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-to-speech", model="facebook/mms-tts-eng")

text_input = """ Essay """

speech_output = pipe(text_input)
print("text to speech audio file: ", speech_output)
# Out:
# Device set to use cpu
# text to speech audio file:  {'audio': array([[ 3.4619242e-02,  3.2735862e-02,  3.0557290e-02, ...,
#          5.7863628e-05,  3.2884949e-05, -1.8456467e-05]], dtype=float32), 'sampling_rate': 16000}

# %%
print(speech_output)
# Out:
# {'audio': array([[-9.4216675e-06, -4.1222134e-05, -3.2540291e-05, ...,
#          6.7345063e-05,  4.8740043e-05, -4.5178367e-05]], dtype=float32), 'sampling_rate': 16000}

# %%
from IPython.display import Audio

print(speech_output)
Audio(speech_output['audio'], rate=speech_output['sampling_rate'])
# Out:
# {'audio': array([[ 3.4619242e-02,  3.2735862e-02,  3.0557290e-02, ...,
#          5.7863628e-05,  3.2884949e-05, -1.8456467e-05]], dtype=float32), 'sampling_rate': 16000}
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from transformers import pipeline
from IPython.display import Audio

pipe = pipeline("text-to-speech", model="facebook/mms-tts-eng")

# Take input from the user
text_to_speak = input("Enter the text you want to convert to speech: ")

# Perform Text-to-Speech
speech_output = pipe(text_to_speak)
print("Text-to-Speech Output Ready!")

# Display audio
Audio(speech_output['audio'], rate=speech_output['sampling_rate'])
# Out:
# Device set to use cpu
# Enter the text you want to convert to speech: this is an audio file
# Text-to-Speech Output Ready!
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from transformers import pipeline

sentiment_pipeline = pipeline("sentiment-analysis", model="distilbert/distilbert-base-uncased-finetuned-sst-2-english")


input_text = """One of the other reviewers has mentioned that after watching just 1 Oz episode you'll be hooked. They are right, as this is exactly what happened with me.<br /><br />The first thing that struck me about Oz was its brutality and unflinching scenes of violence, which set in right from the word GO. Trust me, this is not a show for the faint hearted or timid. This show pulls no punches with regards to drugs, sex or violence. Its is hardcore, in the classic use of the word.<br /><br />It is called OZ as that is the nickname given to the Oswald Maximum Security State Penitentary. It focuses mainly on Emerald City, an experimental section of the prison where all the cells have glass fronts and face inwards, so privacy is not high on the agenda. Em City is home to many..Aryans, Muslims, gangstas, Latinos, Christians, Italians, Irish and more....so scuffles, death stares, dodgy dealings and shady agreements are never far away.<br /><br />I would say the main appeal of the show is due to the fact that it goes where other shows wouldn't dare. Forget pretty pictures painted for mainstream audiences, forget charm, forget romance...OZ doesn't mess around. The first episode I ever saw struck me as so nasty it was surreal, I couldn't say I was ready for it, but as I watched more, I developed a taste for Oz, and got accustomed to the high levels of graphic violence. Not just violence, but injustice (crooked guards who'll be sold out for a nickel, inmates who'll kill on order and get away with it, well mannered, middle class inmates being turned into prison bitches due to their lack of street skills or prison experience) Watching Oz, you may become comfortable with what is uncomfortable viewing....thats if you can get in touch with your darker side."""
result = sentiment_pipeline(input_text)


label = result[0]["label"]
score = result[0]["score"]

print(f"Sentiment: {label}")
print(f"Confidence Score: {score:.2f}")
# Out:
# Device set to use cpu
# Sentiment: NEGATIVE
# Confidence Score: 0.51

# %%
# finalized version
# import statement
from transformers import pipeline
from datasets import load_dataset

# main part

pipe = pipeline("text-classification", model="distilbert/distilbert-base-uncased-finetuned-sst-2-english")


ds = load_dataset("BAJIRAO/imdb_sentiment_3000")

review =

output = pipe(review)
print(f"[Review]: {review}")
print(f"[Sentiment]: {output[0]['label'].capitalize()}")
# Out:
# Device set to use cpu
# [Review]:
# Basically there's a family where a little boy (Jake) thinks there's a zombie in his closet & his
# parents are fighting all the time.<br /><br />This movie is slower than a soap opera... and suddenly,
# Jake decides to become Rambo and kill the zombie.<br /><br />OK, first of all when you're going to
# make a film you must Decide if its a thriller or a drama! As a drama the movie is watchable.
# Parents are divorcing & arguing like in real life. And then we have Jake with his closet which
# totally ruins all the film! I expected to see a BOOGEYMAN similar movie, and instead i watched a
# drama with some meaningless thriller spots.<br /><br />3 out of 10 just for the well playing parents &
# descent dialogs. As for the shots with Jake: just ignore them.
#
# [Sentiment]: Negative

# %%
# Your program goes here

from datasets import load_dataset

dataset = load_dataset("BAJIRAO/imdb_sentiment_3000")
# Access the train split
test_dataset = dataset["train"]

reviews = test_dataset['review'][10:20]     # slicing
sentiments = test_dataset['sentiment'][10:20]

for review, sentiment in zip(reviews, sentiments):
  print(f"[Review]: {review}")
  print(f"[Sentiment]: {sentiment.capitalize()}")

# %%
# import statement
from transformers import pipeline
from datasets import load_dataset


# main part
pipe = pipeline("text-classification",
                model="distilbert/distilbert-base-uncased-finetuned-sst-2-english")

dataset = load_dataset("BAJIRAO/imdb_sentiment_3000")
# Access the train split
test_dataset = dataset["train"]

reviews = test_dataset['review'][:5]     # slicing
sentiments = test_dataset['sentiment'][:5]

for review, sentiment in zip(reviews, sentiments):
  print(f"[Review]: {review}")
  print(f"[Sentiment (Label)]: {sentiment.capitalize()}")
  predicted_sentiment = pipe(review)
  print(f"[Sentiment (prediction)]: {predicted_sentiment[0]['label'].capitalize()}")
  print("")
# Out:
# Device set to use cpu
# ...

# %% [markdown]
# # Task
# Perform sentiment analysis on a user-specified number of reviews from the `BAJIRAO/imdb_sentiment_3000` dataset, displaying the original review, its predicted sentiment, and confidence score for each.

# %% [markdown]
# ## Get Number of Reviews from User
#
# ### Subtask:
# Prompt the user to enter the number of reviews they want to process from the dataset.

# %% [markdown]
# **Reasoning**:
# To get the number of reviews from the user, I need to use the `input()` function and store the result in the specified variable `num_reviews_to_analyze`. I also need to convert the input to an integer.

# %%
num_reviews_to_analyze = int(input("Enter the number of reviews you want to analyze: "))
print(f"You chose to analyze {num_reviews_to_analyze} reviews.")
# Out:
# Enter the number of reviews you want to analyze: 10
# You chose to analyze 10 reviews.

# %% [markdown]
# ## Extract Reviews
#
# ### Subtask:
# Based on the user's input, extract the specified number of reviews from the 'ds' dataset. Ensure handling for cases where the input number might be greater than the available reviews in the dataset.

# %% [markdown]
# **Reasoning**:
# First, I will determine the total number of available reviews in the 'train' split of the `ds` dataset to handle cases where the user's input might exceed the dataset's size. Then, I will calculate the actual number of reviews to extract by taking the minimum of the user-specified count and the total available reviews. Finally, I will extract the specified number of reviews from the dataset.

# %%
total_available_reviews = len(ds['train'])
num_reviews_to_extract = min(num_reviews_to_analyze, total_available_reviews)

reviews_to_process = ds['train']['review'][:num_reviews_to_extract]

print(f"Extracting {len(reviews_to_process)} reviews out of {total_available_reviews} available.")
print(f"First extracted review: {reviews_to_process[0][:100]}...")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-246773300.py in <cell line: 0>()
# ----> 1 total_available_reviews = len(ds['train'])
#       2 num_reviews_to_extract = min(num_reviews_to_analyze, total_available_reviews)
#       3
#       4 reviews_to_process = ds['train']['review'][:num_reviews_to_extract]
#       5
#
# NameError: name 'ds' is not defined

# %% [markdown]
# **Reasoning**:
# The previous code failed because the `ds` variable, which holds the loaded dataset, was not defined in the current execution environment. I need to re-import `load_dataset` and load the dataset into the `ds` variable to make it accessible.

# %%
from datasets import load_dataset

ds = load_dataset("BAJIRAO/imdb_sentiment_3000")

total_available_reviews = len(ds['train'])
num_reviews_to_extract = min(num_reviews_to_analyze, total_available_reviews)

reviews_to_process = ds['train']['review'][:num_reviews_to_extract]

print(f"Extracting {len(reviews_to_process)} reviews out of {total_available_reviews} available.")
print(f"First extracted review: {reviews_to_process[0][:100]}...")
# Out:
# imdb_review.csv: 0.00B [00:00, ?B/s]
# Generating train split:   0%|          | 0/2999 [00:00<?, ? examples/s]
# Extracting 10 reviews out of 2999 available.
# First extracted review: One of the other reviewers has mentioned that after watching just 1 Oz episode you'll be hooked. The...

# %% [markdown]
# **Reasoning**:
# Now that the reviews are extracted and stored in `reviews_to_process`, I will iterate through this list to perform sentiment analysis on each review using the pre-defined `sentiment_pipeline` and then display the results, including the review, sentiment, and confidence score.

# %%
for i, review in enumerate(reviews_to_process):
    # Perform sentiment analysis
    result = sentiment_pipeline(review)
    label = result[0]["label"]
    score = result[0]["score"]

    # Display the results
    print(f"\n--- Review {i+1} ---")
    print(f"Review: {review[:200]}...") # Displaying a snippet of the review
    print(f"Sentiment: {label}")
    print(f"Confidence Score: {score:.2f}")
# Out:
# --- Review 1 ---
# Review: One of the other reviewers has mentioned that after watching just 1 Oz episode you'll be hooked. They are right, as this is exactly what happened with me.<br /><br />The first thing that struck me abo...
# Sentiment: NEGATIVE
# Confidence Score: 0.51
#
# --- Review 2 ---
# Review: A wonderful little production. <br /><br />The filming technique is very unassuming- very old-time-BBC fashion and gives a comforting, and sometimes discomforting, sense of realism to the entire piece...
# Sentiment: POSITIVE
# Confidence Score: 1.00
#
# --- Review 3 ---
# Review: I thought this was a wonderful way to spend time on a too hot summer weekend, sitting in the air conditioned theater and watching a light-hearted comedy. The plot is simplistic, but the dialogue is wi...
# Sentiment: POSITIVE
# Confidence Score: 1.00
#
# --- Review 4 ---
# ...

# %%
from transformers import pipeline
from PIL import Image

# Streamlit UI
print("Title: Age Classification using ViT")

# Load the age classification pipeline
# The code below should be placed in the main part of the program
age_classifier = pipeline("image-classification",
                          model="nateraw/vit-age-classifier")

image_name = "middleagedMan.jpg"
image_name = Image.open(image_name).convert("RGB")

# Classify age
age_predictions = age_classifier(image_name)
print(age_predictions)
age_predictions = sorted(age_predictions, key=lambda x: x['score'], reverse=True)

# Display results
print("Predicted Age Range:")
print(f"Age range: {age_predictions[0]['label']}")
# Out:
# Title: Age Classification using ViT
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/850 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/343M [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/197 [00:00<?, ?B/s]
# Fast image processor class <class 'transformers.models.vit.image_processing_vit_fast.ViTImageProcessorFast'> is available for this model. Using slow image processor class. To use the fast image processor class set `use_fast=True`.
# ...

# %%
from transformers import pipeline
from PIL import Image

# Streamlit UI
print("Title: Age Classification using ViT")

# Load the age classification pipeline
# The code below should be placed in the main part of the program
age_classifier = pipeline("image-classification",
                          model="nateraw/vit-age-classifier")

image_name = input("Enter image file name: ")

age_predictions = age_classifier(image_name)
print(age_predictions)
# Out:
# Title: Age Classification using ViT
# Fast image processor class <class 'transformers.models.vit.image_processing_vit_fast.ViTImageProcessorFast'> is available for this model. Using slow image processor class. To use the fast image processor class set `use_fast=True`.
# Device set to use cpu
# Enter image file name: middleagedMan.jpg
# [{'label': '30-39', 'score': 0.39598897099494934}, {'label': '40-49', 'score': 0.2906949520111084}, {'label': '20-29', 'score': 0.1438731849193573}, {'label': '50-59', 'score': 0.13614973425865173}, {'label': '60-69', 'score': 0.025165656581521034}]

# %%
sorted(age_predictions, key=lambda x: x['score'], reverse=True)
# Out:
# [{'label': '30-39', 'score': 0.39598897099494934},
#  {'label': '40-49', 'score': 0.2906949520111084},
#  {'label': '20-29', 'score': 0.1438731849193573},
#  {'label': '50-59', 'score': 0.13614973425865173},
#  {'label': '60-69', 'score': 0.025165656581521034}]

# %%
print(age_predictions[0]['label'])
print(f"Age range is: {age_predictions[0]['label']}")
# Out:
# 30-39
# Age range is: 30-39

# %%
#import part

from transformers import pipeline
from PIL import Image

#image function
def image_classification(image_name):
    # Load the age classification pipeline
    # The code below should be placed in the main part of the program
    age_classifier = pipeline("image-classification",
                              model="nateraw/vit-age-classifier")

    # Classify age
    age_predictions = age_classifier(image_name)
    age_predictions = sorted(age_predictions, key=lambda x: x['score'], reverse=True)

    return age_predictions[0]['label']

#primary function
def main():
    # Streamlit UI
    print("Title: Age Classification using ViT")


    image_name = "middleagedMan.jpg"
    image_name = Image.open(image_name).convert("RGB")
    age_group = image_classification(image_name=image_name)


    # Display results
    print(f"Predicted Age Range: {age_group}")



#main
if __name__ == "__main__":
    main()
# Out:
# Title: Age Classification using ViT
# Fast image processor class <class 'transformers.models.vit.image_processing_vit_fast.ViTImageProcessorFast'> is available for this model. Using slow image processor class. To use the fast image processor class set `use_fast=True`.
# Device set to use cpu
# Predicted Age Range: 30-39
